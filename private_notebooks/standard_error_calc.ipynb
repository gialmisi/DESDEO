# %%
import polars as pl

from pathlib import Path

problem_name = "branin"
mode = "baseline"
n_gen = 100
n_runs = 1000
ct = "5p0"
pop_size = 6

data_root = Path()
file_ext = "parquet"
results_path = Path("results/")
file_name = Path(data_root / f"{problem_name}_{mode}_gen{n_gen}_runs{n_runs}_ct{ct}_psize{pop_size}.{file_ext}")

df = pl.read_parquet(results_path / file_name)

df.sample(10)
# Out:
# shape: (10, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ x_1       ┆ x_2       ┆ f_1       ┆ f_1_min   ┆ … ┆ best_mean ┆ best_std  ┆ best_uppe ┆ best_low │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ r         ┆ er       │
# │ f64       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 3.152108  ┆ 0.333584  ┆ -261.9973 ┆ -261.9973 ┆ … ┆ -238.6801 ┆ 29.750956 ┆ -208.9291 ┆ -268.431 │
# │           ┆           ┆ 72        ┆ 72        ┆   ┆ 45        ┆           ┆ 89        ┆ 102      │
# │ 9.110133  ┆ 0.138454  ┆ -221.6573 ┆ -221.6573 ┆ … ┆ -239.9093 ┆ 29.840958 ┆ -210.0683 ┆ -269.750 │
# ...
